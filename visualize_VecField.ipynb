# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure()
lx,ly ,lz= 10 ,10 , 10
gridwidth=2
x, y , z = np.meshgrid(np.arrange(-lx,lx, gridwidth), np.arrange(-ly, ly, gridwidth), np.arrange(-lz, lz, gridwitdh))

u = x**2 * y

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = x**2 * y
v = -2*x*z
w = 2*y*z
ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
